# %% [markdown]
# <a href="https://colab.research.google.com/github/FarahLebdeh/Mobiclinic/blob/main/Graduation_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Connect Google Colab with Google Drive**

# %%
from google.colab import drive
from os.path import join
drive.mount('/content/drive')
# drive.mount('%cd /content/drive/MyDrive/Github/')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Import Libraries**

# %%
import os
import glob
import pandas as pd 
import random
import numpy as np 
import nltk
import string
from joblib import dump, load
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
nltk.download('stopwords')
nltk.download('wordnet')
stop = stopwords.words('arabic')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # **Read Text File**

# %% [markdown]
# **Print name of files**

# %%
# ---------------------- Print name of files as Array ------------------
os.chdir(r'/content/drive/MyDrive/Colab Notebooks/DataSets/')
my_files = glob.glob('*.txt')
print(my_files)
# ---------------------- Print name of files as column ------------------
# txtfiles = []
# for file in glob.glob("*.txt"):
#     txtfiles.append(file)
#     print(file)
# Out:
# []

# %% [markdown]
# **Print content of files then save all the data in one text file "Output.txt"**

# %%
for filename in os.listdir("/content/drive/MyDrive/Colab Notebooks/DataSets/Najat"):
   with open(os.path.join("/content/drive/MyDrive/Colab Notebooks/DataSets/Najat", filename), 'r') as f:
       text = f.read()
      #  to print content
       print(filename+" || " + text )
        # save name of file and content      
      #  print(filename+ " || " + text , file=open("/content/drive/MyDrive/Colab Notebooks/Output/Output.txt", "a"))
# Out:
# EX1_11_1_22_160_47_F.txt || 02:19|1,0,0,2,-2,-2,1,0,0,-3,-2,-1,1,0,0,-3,-2,-1,1,0,0,-13,-2,-5,1,0,0,-6,-2,-5,1,1,0,-2,-2,2 02:19|1,0,0,3,-4,0,1,0,0,0,-2,0,1,0,0,1,-2,0,1,0,0,1,1,0,1,0,0,0,-5,-2,1,1,0,0,-4,0 02:19|1,0,0,6,-4,0,1,0,0,0,-2,0,1,0,0,-1,-2,0,1,0,0,-8,-5,-2,1,0,0,-1,-2,-2,1,1,0,-8,-8,0 02:19|1,0,0,4,-3,0,1,0,0,0,-2,0,1,0,0,-2,-2,0,1,0,0,-14,-5,-6,1,0,0,-2,-2,-2,1,1,0,-2,-7,2 02:20|1,0,0,4,-2,0,1,0,0,-1,-2,0,1,0,0,0,-1,0,1,0,0,-6,-2,0,1,0,0,-2,-2,-2,1,1,0,-1,-2,2 02:20|1,0,0,3,-2,0,1,0,0,-1,-2,0,1,0,0,-2,-2,0,1,0,0,-10,-2,0,1,0,0,-6,-2,-4,1,1,0,-1,-2,1 02:20|1,0,0,4,-3,0,1,0,0,-1,-2,0,1,0,0,-1,-2,0,1,0,0,-10,-2,0,1,0,0,-6,-3,-4,1,1,0,-4,-7,4 02:20|1,0,0,4,-5,1,1,0,0,0,-3,0,1,0,0,0,-2,0,1,0,0,0,-3,0,1,0,0,0,-3,0,1,1,0,0,-3,0 02:20|1,0,0,1,-2,1,1,0,0,1,-2,0,1,0,0,0,-2,0,1,0,0,0,-2,1,1,0,0,0,-2,0,1,1,0,0,-2,0 02:20|1,0,0,0,-2,0,1,0,0,1,-2,0,1,0,0,1,-2,0,1,0,0,0,-2,1,1,0,0,-2,-2,-1,1,1,-1,-2,-2,0 02:20|1,0,0,3,-2,0,1,0,0,0,-2,0,1,0,0,-1,-2,0,1,0,0,-10,-2,0,1,0,0,-5,-2,-2,1,1,0,-
# ...
